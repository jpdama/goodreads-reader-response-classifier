# %% [markdown]
# # 03 GenAI Benchmark
#
# Purpose: run comparable prompts across at least six models and evaluate against human consensus labels.

# %% [markdown]
# Set provider API keys as environment variables before running: `OPENAI_API_KEY`, `ANTHROPIC_API_KEY`, `GOOGLE_API_KEY`.

# %%
# !python scripts/genai_benchmark.py --supplier OpenAI --model gpt-4o-mini --input data/processed/holdout_locked.csv --output data/results/holdout_openai_gpt-4o-mini.csv

# %%
# !python scripts/evaluate_predictions.py --gold data/results/holdout_human_consensus.csv --pred data/results/holdout_openai_gpt-4o-mini.csv --output data/results/eval_openai_gpt-4o-mini.json

# %% [markdown]
# Repeat the two cells above for every model in `config/genai_models.yaml`.
