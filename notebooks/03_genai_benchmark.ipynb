# %% [markdown]
# # 03 GenAI Benchmark
#
# Purpose: run comparable prompts across at least six models and evaluate against human consensus labels.

# %% [markdown]
# Set provider API keys as environment variables before running: `OPENAI_API_KEY`, `ANTHROPIC_API_KEY`, `GOOGLE_API_KEY`.

# %%
import os
#os.chdir("/Users/eliza/classifier/goodreads-reader-response-classifier")
os.environ["OPENAI_API_KEY"] = ""
# !python scripts/genai_benchmark.py --supplier OpenAI --model gpt-4o-mini --input data/processed/holdout_locked.csv --output data/results/holdout_openai_gpt-4o-mini.csv
# Out:
# OpenAI/gpt-4o-mini: labeled 50 rows
# OpenAI/gpt-4o-mini: labeled 100 rows
# OpenAI/gpt-4o-mini: labeled 150 rows
# OpenAI/gpt-4o-mini: labeled 200 rows
# OpenAI/gpt-4o-mini: labeled 250 rows
# OpenAI/gpt-4o-mini: labeled 300 rows
# OpenAI/gpt-4o-mini: labeled 350 rows
# OpenAI/gpt-4o-mini: labeled 400 rows
# OpenAI/gpt-4o-mini: labeled 450 rows
# OpenAI/gpt-4o-mini: labeled 500 rows
# OpenAI/gpt-4o-mini: labeled 550 rows
# OpenAI/gpt-4o-mini: labeled 600 rows
# OpenAI/gpt-4o-mini: labeled 650 rows
# OpenAI/gpt-4o-mini: labeled 700 rows
# OpenAI/gpt-4o-mini: labeled 750 rows
# OpenAI/gpt-4o-mini: labeled 800 rows
# OpenAI/gpt-4o-mini: labeled 850 rows
# OpenAI/gpt-4o-mini: labeled 900 rows
# OpenAI/gpt-4o-mini: labeled 950 rows
# OpenAI/gpt-4o-mini: labeled 1000 rows
# {
#   "supplier": "OpenAI",
#   "model": "gpt-4o-mini",
#   "input_path": "data/results/holdout_human_consensus.csv",
#   "output_path": "data/results/holdout_openai_gpt-4o-mini.csv",
#   "rows": 1000,
# ...

# %%
# !python scripts/evaluate_predictions.py --gold data/results/holdout_human_consensus.csv --pred data/results/holdout_openai_gpt-4o-mini.csv --output data/results/eval_openai_gpt-4o-mini.json
# Out:
# {
#   "gold_path": "data/results/holdout_human_consensus.csv",
#   "prediction_path": "data/results/holdout_openai_gpt-4o-mini.csv",
#   "n_matched": 1000,
#   "emotions": {
#     "sample_f1": 0.4544309523809524,
#     "macro_f1": 0.39386931013613474,
#     "micro_f1": 0.526564344746163,
#     "exact_match": 0.167,
#     "per_class": {
#       "joy": {
#         "precision": 0.19665809768637532,
#         "recall": 0.9870967741935484,
#         "f1": 0.3279742765273312,
#         "support": 155
#       },
#       "love": {
#         "precision": 0.7832422586520947,
#         "recall": 0.8669354838709677,
#         "f1": 0.8229665071770335,
#         "support": 496
#       },
#       "surprise": {
#         "precision": 0.42105263157894735,
#         "recall": 0.5773195876288659,
#         "f1": 0.48695652173913045,
#         "support": 97
#       },
#       "contentment": {
#         "precision": 0.2077922077922078,
#         "recall": 0.13008130081300814,
#         "f1": 0.16,
# ...

# %%
import os
os.environ["OPENAI_API_KEY"] = ""
#os.chdir("/Users/eliza/classifier/goodreads-reader-response-classifier")
# !python scripts/genai_benchmark.py --supplier OpenAI --model gpt-4.1-mini --input data/processed/holdout_locked.csv --output data/results/holdout_openai_gpt-4.1-mini.csv
# Out:
# OpenAI/gpt-4.1-mini: labeled 50 rows
# OpenAI/gpt-4.1-mini: labeled 100 rows
# OpenAI/gpt-4.1-mini: labeled 150 rows
# OpenAI/gpt-4.1-mini: labeled 200 rows
# OpenAI/gpt-4.1-mini: labeled 250 rows
# OpenAI/gpt-4.1-mini: labeled 300 rows
# OpenAI/gpt-4.1-mini: labeled 350 rows
# OpenAI/gpt-4.1-mini: labeled 400 rows
# OpenAI/gpt-4.1-mini: labeled 450 rows
# OpenAI/gpt-4.1-mini: labeled 500 rows
# OpenAI/gpt-4.1-mini: labeled 550 rows
# OpenAI/gpt-4.1-mini: labeled 600 rows
# OpenAI/gpt-4.1-mini: labeled 650 rows
# OpenAI/gpt-4.1-mini: labeled 700 rows
# OpenAI/gpt-4.1-mini: labeled 750 rows
# OpenAI/gpt-4.1-mini: labeled 800 rows
# OpenAI/gpt-4.1-mini: labeled 850 rows
# OpenAI/gpt-4.1-mini: labeled 900 rows
# OpenAI/gpt-4.1-mini: labeled 950 rows
# OpenAI/gpt-4.1-mini: labeled 1000 rows
# {
#   "supplier": "OpenAI",
#   "model": "gpt-4.1-mini",
#   "input_path": "data/results/holdout_human_consensus.csv",
#   "output_path": "data/results/holdout_openai_gpt-4.1-mini.csv",
# ...

# %%
# !python scripts/evaluate_predictions.py --gold data/results/holdout_human_consensus.csv --pred data/results/holdout_openai_gpt-4.1-mini.csv --output data/results/eval_openai_gpt-4.1-mini.json
# Out:
# {
#   "gold_path": "data/results/holdout_human_consensus.csv",
#   "prediction_path": "data/results/holdout_openai_gpt-4.1-mini.csv",
#   "n_matched": 1000,
#   "emotions": {
#     "sample_f1": 0.4848444444444444,
#     "macro_f1": 0.41329902061068563,
#     "micro_f1": 0.5411103302881237,
#     "exact_match": 0.098,
#     "per_class": {
#       "joy": {
#         "precision": 0.20441988950276244,
#         "recall": 0.9548387096774194,
#         "f1": 0.33674630261660976,
#         "support": 155
#       },
#       "love": {
#         "precision": 0.763458401305057,
#         "recall": 0.9435483870967742,
#         "f1": 0.8440036068530208,
#         "support": 496
#       },
#       "surprise": {
#         "precision": 0.3333333333333333,
#         "recall": 0.7319587628865979,
#         "f1": 0.45806451612903226,
#         "support": 97
#       },
#       "contentment": {
#         "precision": 0.2017167381974249,
#         "recall": 0.3821138211382114,
# ...

# %%
import os
os.environ["ANTHROPIC_API_KEY"] = ""
#os.chdir("/Users/eliza/classifier/goodreads-reader-response-classifier")
# !python scripts/genai_benchmark.py --supplier Anthropic --model claude-sonnet-4-6 --input data/processed/holdout_real_reviews.csv --output data/results/holdout_anthropic_claude-sonnet-4-6.csv
# Out:
# Anthropic/claude-sonnet-4-6: labeled 50 rows
# Anthropic/claude-sonnet-4-6: labeled 100 rows
# Anthropic/claude-sonnet-4-6: labeled 150 rows
# Anthropic/claude-sonnet-4-6: labeled 200 rows
# Anthropic/claude-sonnet-4-6: labeled 250 rows
# Anthropic/claude-sonnet-4-6: labeled 300 rows
# Anthropic/claude-sonnet-4-6: labeled 350 rows
# Anthropic/claude-sonnet-4-6: labeled 400 rows
# Anthropic/claude-sonnet-4-6: labeled 450 rows
# Anthropic/claude-sonnet-4-6: labeled 500 rows
# Anthropic/claude-sonnet-4-6: labeled 550 rows
# Anthropic/claude-sonnet-4-6: labeled 600 rows
# Anthropic/claude-sonnet-4-6: labeled 650 rows
# Anthropic/claude-sonnet-4-6: labeled 700 rows
# Anthropic/claude-sonnet-4-6: labeled 750 rows
# Anthropic/claude-sonnet-4-6: labeled 800 rows
# Anthropic/claude-sonnet-4-6: labeled 850 rows
# Anthropic/claude-sonnet-4-6: labeled 900 rows
# Anthropic/claude-sonnet-4-6: labeled 950 rows
# Anthropic/claude-sonnet-4-6: labeled 1000 rows
# {
#   "supplier": "Anthropic",
# ...

# %%
# !python scripts/evaluate_predictions.py --gold data/results/holdout_human_consensus.csv --pred data/results/holdout_anthropic_claude-sonnet-4-6.csv --output data/results/eval_anthropic_claude-sonnet-4-6.json
# Out:
# {
#   "gold_path": "data/results/holdout_human_consensus.csv",
#   "prediction_path": "data/results/holdout_anthropic_claude-sonnet-4-6.csv",
#   "n_matched": 1000,
#   "emotions": {
#     "sample_f1": 0.4642650793650794,
#     "macro_f1": 0.4105197349036463,
#     "micro_f1": 0.5144775493075955,
#     "exact_match": 0.07,
#     "per_class": {
#       "joy": {
#         "precision": 0.20133333333333334,
#         "recall": 0.9741935483870968,
#         "f1": 0.33370165745856356,
#         "support": 155
#       },
#       "love": {
#         "precision": 0.7577235772357723,
#         "recall": 0.9395161290322581,
#         "f1": 0.8388838883888389,
#         "support": 496
#       },
#       "surprise": {
#         "precision": 0.2616487455197133,
#         "recall": 0.7525773195876289,
#         "f1": 0.3882978723404255,
#         "support": 97
#       },
#       "contentment": {
#         "precision": 0.1958041958041958,
#         "recall": 0.6829268292682927,
# ...

# %%
import os
os.environ["DEEPSEEK_API_KEY"] = ""
#os.chdir("/Users/eliza/classifier/goodreads-reader-response-classifier")
# !python scripts/genai_benchmark.py --supplier DeepSeek --model deepseek-chat --input data/processed/holdout_real_reviews.csv --output data/results/holdout_deepseek_deepseek-chat.csv
# Out:
# DeepSeek/deepseek-chat: labeled 50 rows
# DeepSeek/deepseek-chat: labeled 100 rows
# DeepSeek/deepseek-chat: labeled 150 rows
# DeepSeek/deepseek-chat: labeled 200 rows
# DeepSeek/deepseek-chat: labeled 250 rows
# DeepSeek/deepseek-chat: labeled 300 rows
# DeepSeek/deepseek-chat: labeled 350 rows
# DeepSeek/deepseek-chat: labeled 400 rows
# DeepSeek/deepseek-chat: labeled 450 rows
# DeepSeek/deepseek-chat: labeled 500 rows
# DeepSeek/deepseek-chat: labeled 550 rows
# DeepSeek/deepseek-chat: labeled 600 rows
# DeepSeek/deepseek-chat: labeled 650 rows
# DeepSeek/deepseek-chat: labeled 700 rows
# DeepSeek/deepseek-chat: labeled 750 rows
# DeepSeek/deepseek-chat: labeled 800 rows
# DeepSeek/deepseek-chat: labeled 850 rows
# DeepSeek/deepseek-chat: labeled 900 rows
# DeepSeek/deepseek-chat: labeled 950 rows
# DeepSeek/deepseek-chat: labeled 1000 rows
# {
#   "supplier": "DeepSeek",
#   "model": "deepseek-chat",
#   "input_path": "data/processed/holdout_real_reviews.csv",
# ...

# %%
# !python scripts/evaluate_predictions.py --gold data/results/holdout_human_consensus.csv --pred data/results/holdout_deepseek_deepseek-chat.csv --output data/results/eval_deepseek-chat.json
# Out:
# {
#   "gold_path": "data/results/holdout_human_consensus.csv",
#   "prediction_path": "data/results/holdout_deepseek_deepseek-chat.csv",
#   "n_matched": 1000,
#   "emotions": {
#     "sample_f1": 0.49894603174603175,
#     "macro_f1": 0.42360481639564423,
#     "micro_f1": 0.5561608300907912,
#     "exact_match": 0.165,
#     "per_class": {
#       "joy": {
#         "precision": 0.22838499184339314,
#         "recall": 0.9032258064516129,
#         "f1": 0.3645833333333333,
#         "support": 155
#       },
#       "love": {
#         "precision": 0.7556270096463023,
#         "recall": 0.9475806451612904,
#         "f1": 0.8407871198568873,
#         "support": 496
#       },
#       "surprise": {
#         "precision": 0.32038834951456313,
#         "recall": 0.6804123711340206,
#         "f1": 0.43564356435643564,
#         "support": 97
#       },
#       "contentment": {
#         "precision": 0.3488372093023256,
#         "recall": 0.12195121951219512,
# ...

# %%
import os
os.environ["DEEPSEEK_API_KEY"] = ""
#os.chdir("/Users/eliza/classifier/goodreads-reader-response-classifier")
# !python scripts/genai_benchmark.py --supplier DeepSeek --model deepseek-v4-pro --input data/processed/holdout_real_reviews.csv --output data/results/holdout_deepseek-v4-pro.csv
# Out:
# DeepSeek/deepseek-v4-pro: labeled 50 rows
# DeepSeek/deepseek-v4-pro: labeled 100 rows
# ^C
#   File "/Users/eliza/classifier/goodreads-reader-response-classifier/.venv/lib/python3.12/site-packages/openai/_utils/_utils.py", line 287, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/eliza/classifier/goodreads-reader-response-classifier/.venv/lib/python3.12/site-packages/openai/resources/chat/completions/completions.py", line 1211, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/eliza/classifier/goodreads-reader-response-classifier/.venv/lib/python3.12/site-packages/openai/_base_client.py", line 1314, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
# !python scripts/evaluate_predictions.py --gold data/results/holdout_human_consensus.csv --pred data/results/holdout_deepseek-v4-pro.csv --output data/results/eval_deepseek-chat.json
# Out:
# {
#   "gold_path": "data/results/holdout_human_consensus.csv",
#   "prediction_path": "data/results/holdout_deepseek-v4-pro.csv",
#   "n_matched": 3,
#   "emotions": {
#     "sample_f1": 0.7857142857142857,
#     "macro_f1": 0.2333333333333333,
#     "micro_f1": 0.8,
#     "exact_match": 0.3333333333333333,
#     "per_class": {
#       "joy": {
#         "precision": 0.6666666666666666,
#         "recall": 1.0,
#         "f1": 0.8,
#         "support": 2
#       },
#       "love": {
#         "precision": 0.0,
#         "recall": 0.0,
#         "f1": 0.0,
#         "support": 2
#       },
#       "surprise": {
#         "precision": 1.0,
#         "recall": 1.0,
#         "f1": 1.0,
#         "support": 1
#       },
#       "contentment": {
#         "precision": 0.0,
#         "recall": 0.0,
#         "f1": 0.0,
#         "support": 0
#       },
#       "interest": {
#         "precision": 1.0,
#         "recall": 1.0,
#         "f1": 1.0,
#         "support": 3
#       },
# ...

# %%
import os
os.environ["XAI_API_KEY"] = ""
#os.chdir("/Users/eliza/classifier/goodreads-reader-response-classifier")
# !python scripts/genai_benchmark.py --supplier Grok --model grok-3-fast --input data/processed/holdout_real_reviews.csv --output data/results/holdout_grok-3-fast.csv
# Out:
# Grok/grok-3-fast: labeled 50 rows
# Grok/grok-3-fast: labeled 100 rows
# Grok/grok-3-fast: labeled 150 rows
# Grok/grok-3-fast: labeled 200 rows
# Grok/grok-3-fast: labeled 250 rows
# Grok/grok-3-fast: labeled 300 rows
# Grok/grok-3-fast: labeled 350 rows
# Grok/grok-3-fast: labeled 400 rows
# Grok/grok-3-fast: labeled 450 rows
# Grok/grok-3-fast: labeled 500 rows
# Grok/grok-3-fast: labeled 550 rows
# Grok/grok-3-fast: labeled 600 rows
# Grok/grok-3-fast: labeled 650 rows
# Grok/grok-3-fast: labeled 700 rows
# Grok/grok-3-fast: labeled 750 rows
# Grok/grok-3-fast: labeled 800 rows
# Grok/grok-3-fast: labeled 850 rows
# Grok/grok-3-fast: labeled 900 rows
# Grok/grok-3-fast: labeled 950 rows
# Grok/grok-3-fast: labeled 1000 rows
# {
#   "supplier": "Grok",
#   "model": "grok-3-fast",
#   "input_path": "data/processed/holdout_real_reviews.csv",
#   "output_path": "data/results/holdout_grok-3-fast.csv",
#   "rows": 1000,
#   "parse_or_api_failures": 0,
# ...

# %%
# !python scripts/evaluate_predictions.py --gold data/results/holdout_human_consensus.csv --pred data/results/holdout_grok-3-fast.csv --output data/results/eval_grok-3-fast.json
# Out:
# {
#   "gold_path": "data/results/holdout_human_consensus.csv",
#   "prediction_path": "data/results/holdout_grok-3-fast.csv",
#   "n_matched": 1000,
#   "emotions": {
#     "sample_f1": 0.4897095238095238,
#     "macro_f1": 0.4513472608489604,
#     "micro_f1": 0.5505344995140914,
#     "exact_match": 0.135,
#     "per_class": {
#       "joy": {
#         "precision": 0.19946091644204852,
#         "recall": 0.9548387096774194,
#         "f1": 0.32998885172798215,
#         "support": 155
#       },
#       "love": {
#         "precision": 0.7576736672051696,
#         "recall": 0.9455645161290323,
#         "f1": 0.841255605381166,
#         "support": 496
#       },
#       "surprise": {
#         "precision": 0.31555555555555553,
#         "recall": 0.7319587628865979,
#         "f1": 0.4409937888198758,
#         "support": 97
#       },
#       "contentment": {
#         "precision": 0.1896551724137931,
#         "recall": 0.2682926829268293,
#         "f1": 0.2222222222222222,
# ...

# %%
import os
os.environ["XAI_API_KEY"] = ""
#os.chdir("/Users/eliza/classifier/goodreads-reader-response-classifier")
# !python scripts/genai_benchmark.py --supplier Grok --model grok-4-1-fast --input data/processed/holdout_real_reviews.csv --output data/results/holdout_grok-4-1-fast.csv
# Out:
# Grok/grok-4-1-fast: labeled 50 rows
# Grok/grok-4-1-fast: labeled 100 rows
# Grok/grok-4-1-fast: labeled 150 rows
# Grok/grok-4-1-fast: labeled 200 rows
# Grok/grok-4-1-fast: labeled 250 rows
# Grok/grok-4-1-fast: labeled 300 rows
# Grok/grok-4-1-fast: labeled 350 rows
# Grok/grok-4-1-fast: labeled 400 rows
# Grok/grok-4-1-fast: labeled 450 rows
# Grok/grok-4-1-fast: labeled 500 rows
# Grok/grok-4-1-fast: labeled 550 rows
# Grok/grok-4-1-fast: labeled 600 rows
# Grok/grok-4-1-fast: labeled 650 rows
# Grok/grok-4-1-fast: labeled 700 rows
# Grok/grok-4-1-fast: labeled 750 rows
# Grok/grok-4-1-fast: labeled 800 rows
# Grok/grok-4-1-fast: labeled 850 rows
# Grok/grok-4-1-fast: labeled 900 rows
# Grok/grok-4-1-fast: labeled 950 rows
# Grok/grok-4-1-fast: labeled 1000 rows
# {
#   "supplier": "Grok",
#   "model": "grok-4-1-fast",
#   "input_path": "data/processed/holdout_real_reviews.csv",
#   "output_path": "data/results/holdout_grok-4-1-fast.csv",
#   "rows": 1000,
# ...

# %%
# !python scripts/evaluate_predictions.py --gold data/results/holdout_human_consensus.csv --pred data/results/holdout_grok-4-1-fast.csv --output data/results/eval_grok-4-1-fast.json
# Out:
# {
#   "gold_path": "data/results/holdout_human_consensus.csv",
#   "prediction_path": "data/results/holdout_grok-4-1-fast.csv",
#   "n_matched": 1000,
#   "emotions": {
#     "sample_f1": 0.47635,
#     "macro_f1": 0.420523908604084,
#     "micro_f1": 0.5362739408009286,
#     "exact_match": 0.199,
#     "per_class": {
#       "joy": {
#         "precision": 0.218213058419244,
#         "recall": 0.8193548387096774,
#         "f1": 0.344640434192673,
#         "support": 155
#       },
#       "love": {
#         "precision": 0.7872727272727272,
#         "recall": 0.8729838709677419,
#         "f1": 0.8279158699808795,
#         "support": 496
#       },
#       "surprise": {
#         "precision": 0.2992125984251969,
#         "recall": 0.7835051546391752,
#         "f1": 0.43304843304843305,
#         "support": 97
#       },
#       "contentment": {
#         "precision": 0.5625,
#         "recall": 0.07317073170731707,
#         "f1": 0.12949640287769784,
# ...

# %% [markdown]
# Repeat the two cells above for every model in `config/genai_models.yaml`.
