# %% [markdown]
# # 02 Human Reliability
#
# Purpose: create a three-coder labeling sheet for the locked holdout and compute agreement after labels are entered.

# %%
# !python scripts/make_labeling_sheet.py --input data/processed/holdout_locked.csv --output data/labels/holdout_human_labeling_sheet.csv --coder-count 3

# %%
# !python scripts/make_labeling_workbook.py --input data/processed/holdout_locked.csv --output data/labels/holdout_labeling_workbook.xlsx --pilot-size 60

# %% [markdown]
# After three coders complete the sheet, run the reliability report.

# %%
# !python scripts/reliability_report.py --input data/labels/holdout_human_labeling_sheet.csv --output-dir data/results --coder-count 3
