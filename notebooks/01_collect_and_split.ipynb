# %% [markdown]
# # 01 Collect and Split Goodreads Reviews
#
# Purpose: sample 16,000 UCSD Goodreads reviews, clean the text, and lock the train/test/holdout split.

# %% [markdown]
# Current run uses `/Users/pod/Desktop/goodreads_reviews_spoiler.json`. If the final project must be strictly Young Adult, replace this input with `data/raw/goodreads_reviews_young_adult.json.gz` and rerun the same cells.

# %%
# !python scripts/collect_goodreads.py --input /Users/pod/Desktop/goodreads_reviews_spoiler.json --output data/interim/goodreads_spoiler_sample_16200.csv --sample-size 16200 --seed 20260426

# %%
# !python scripts/preprocess_split.py --input data/interim/goodreads_spoiler_sample_16200.csv --output-dir data/processed --holdout-size 1000 --test-size 3000 --train-size 12000 --seed 20260426

# %%
import json, pathlib
print(pathlib.Path('data/processed/split_stats.json').read_text())
